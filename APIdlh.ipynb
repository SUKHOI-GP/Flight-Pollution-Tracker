# %%
import requests

# %%
url = "https://opensky-network.org/api/states/all"
params = {
    "lamin": 47, 
    "lamax": 55,
    "lomin": 5, 
    "lomax": 15
}

# %%
response = request.get(url, params=params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = request.get(url, params=params)
#
# NameError: name 'request' is not defined

# %%
if response.status_code == 200:
    data = response.json()
    fluge_dlh = [s for s in data["states"] if s[1] and s[1].startswith("DLH")]
    print("Lufhansa über Deutschland")
    for flug in fluge_dhl:
        callsign = flug[1]
        latitud = flug[6]
        longitud = flug[5]
        altitud = flug[7]
        print(f"{callsign}: lat={latitud}, lon={longitud}, alt={altitud}")
else:
        print("Error:", response.status_code)
